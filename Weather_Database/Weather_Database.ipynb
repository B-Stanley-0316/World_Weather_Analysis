# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # If the city is unique, then we will add it to the cities list.
    if city_name not in cities:
        cities.append(city_name)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
import sys
sys.path.append('..')
from config import weather_api_key

#Import time & datetime module.
import time
from datetime import datetime

# %%
# Starting URL for Weather API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7de56bf7736fce48d56dad3b77b832c9

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san juan
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | nuuk
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | chotila
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | edd
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | vicuna
# Processing Record 12 of Set 1 | hofn
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | yumen
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | senanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | kjollefjord
# Processing Record 21 of Set 1 | burriana
# Processing Record 22 of Set 1 | phan thiet
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | huarmey
# Processing Record 25 of Set 1 | narsaq
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | sambava
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | andenes
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | rey bouba
# Processing Record 32 of Set 1 | banda aceh
# Processing Record 33 of Set 1 | el vigia
# Processing Record 34 of Set 1 | vao
# Processing Record 35 of Set 1 | puerto escondido
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | owo
# Processing Record 38 of Set 1 | wakkanai
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | fairbanks
# Processing Record 41 of Set 1 | phonhong
# Processing Record 42 of Set 1 | arlit
# Processing Record 43 of Set 1 | ketchikan
# Processing Record 44 of Set 1 | daru
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | san cristobal
# Processing Record 50 of Set 1 | huilong
# Processing Record 1 of Set 2 | masterton
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | cooma
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | havre
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | deputatskiy
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | udachnyy
# Processing Record 15 of Set 2 | caravelas
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | muros
# Processing Record 20 of Set 2 | sompeta
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | aklavik
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | ngunguru
# Processing Record 25 of Set 2 | prieska
# Processing Record 26 of Set 2 | ozinki
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | marzuq
# Processing Record 29 of Set 2 | touros
# Processing Record 30 of Set 2 | huazolotitlan
# City not found. Skipping...
# Processing Record 31 of Set 2 | kaeo
# Processing Record 32 of Set 2 | anadyr
# Processing Record 33 of Set 2 | havre-saint-pierre
# Processing Record 34 of Set 2 | port blair
# Processing Record 35 of Set 2 | ocampo
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | waipawa
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | urdoma
# Processing Record 41 of Set 2 | iwanai
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | santa rosa
# Processing Record 48 of Set 2 | harper
# Processing Record 49 of Set 2 | aykhal
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | port hedland
# Processing Record 2 of Set 3 | dengzhou
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | changqing
# Processing Record 6 of Set 3 | poso
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | bugama
# Processing Record 9 of Set 3 | qaqortoq
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | makat
# Processing Record 14 of Set 3 | lamu
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | oktyabrskiy
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | palmer
# Processing Record 23 of Set 3 | rawson
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | grindavik
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | lincoln
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | san lawrenz
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | nabire
# Processing Record 36 of Set 3 | watrous
# Processing Record 37 of Set 3 | severo-yeniseyskiy
# Processing Record 38 of Set 3 | mantena
# Processing Record 39 of Set 3 | geraldton
# Processing Record 40 of Set 3 | pavlodar
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | nazret
# Processing Record 45 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 3 | murgab
# Processing Record 47 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 48 of Set 3 | el reno
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | kieta
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | kharabali
# Processing Record 4 of Set 4 | emba
# Processing Record 5 of Set 4 | maldonado
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | milkovo
# Processing Record 8 of Set 4 | skjervoy
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | abeche
# Processing Record 12 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 4 | garissa
# Processing Record 14 of Set 4 | luwuk
# Processing Record 15 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 4 | dikson
# Processing Record 17 of Set 4 | makkaveyevo
# Processing Record 18 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 4 | erdaojiang
# Processing Record 20 of Set 4 | havoysund
# Processing Record 21 of Set 4 | sumenep
# Processing Record 22 of Set 4 | parainen
# Processing Record 23 of Set 4 | houma
# Processing Record 24 of Set 4 | acapulco
# Processing Record 25 of Set 4 | tromso
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | marhaura
# Processing Record 28 of Set 4 | peniche
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | rocha
# Processing Record 31 of Set 4 | mehriz
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | garowe
# Processing Record 34 of Set 4 | dwarka
# Processing Record 35 of Set 4 | san rafael
# Processing Record 36 of Set 4 | svetlyy
# Processing Record 37 of Set 4 | tuktoyaktuk
# Processing Record 38 of Set 4 | shushtar
# Processing Record 39 of Set 4 | pierre
# Processing Record 40 of Set 4 | saint-francois
# Processing Record 41 of Set 4 | kamaishi
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | porto belo
# Processing Record 44 of Set 4 | verkh-usugli
# Processing Record 45 of Set 4 | mar del plata
# Processing Record 46 of Set 4 | novikovo
# Processing Record 47 of Set 4 | sadovoye
# Processing Record 48 of Set 4 | quelimane
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | naryan-mar
# Processing Record 2 of Set 5 | coos bay
# Processing Record 3 of Set 5 | viedma
# Processing Record 4 of Set 5 | bereda
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | nuevo progreso
# Processing Record 7 of Set 5 | gaoua
# Processing Record 8 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 5 | gisborne
# Processing Record 10 of Set 5 | chulman
# Processing Record 11 of Set 5 | esperance
# Processing Record 12 of Set 5 | trowbridge
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | roald
# Processing Record 17 of Set 5 | chifeng
# Processing Record 18 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 19 of Set 5 | itarema
# Processing Record 20 of Set 5 | sandnessjoen
# Processing Record 21 of Set 5 | svetlaya
# Processing Record 22 of Set 5 | mana
# Processing Record 23 of Set 5 | gladstone
# Processing Record 24 of Set 5 | port-gentil
# Processing Record 25 of Set 5 | lorengau
# Processing Record 26 of Set 5 | abu kamal
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | kulhudhuffushi
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | dzaoudzi
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | erdenet
# Processing Record 34 of Set 5 | kachiry
# Processing Record 35 of Set 5 | luderitz
# Processing Record 36 of Set 5 | wanning
# Processing Record 37 of Set 5 | vestmannaeyjar
# Processing Record 38 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 5 | tanhacu
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | colesberg
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | carpentersville
# Processing Record 44 of Set 5 | kantang
# Processing Record 45 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 5 | boende
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | nhamunda
# Processing Record 49 of Set 5 | fort nelson
# Processing Record 50 of Set 5 | rincon
# Processing Record 1 of Set 6 | kampot
# Processing Record 2 of Set 6 | nemuro
# Processing Record 3 of Set 6 | garmsar
# Processing Record 4 of Set 6 | owando
# Processing Record 5 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 6 | basoko
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | ray
# Processing Record 10 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | honolulu
# Processing Record 12 of Set 6 | pangnirtung
# Processing Record 13 of Set 6 | racine
# Processing Record 14 of Set 6 | baruun-urt
# Processing Record 15 of Set 6 | lapas
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | acala
# Processing Record 18 of Set 6 | muskego
# Processing Record 19 of Set 6 | bosaso
# Processing Record 20 of Set 6 | cayenne
# Processing Record 21 of Set 6 | limbdi
# Processing Record 22 of Set 6 | mayo
# Processing Record 23 of Set 6 | sandakan
# Processing Record 24 of Set 6 | abong mbang
# Processing Record 25 of Set 6 | bairiki
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | biak
# Processing Record 28 of Set 6 | porto walter
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | nikel
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | nampula
# Processing Record 33 of Set 6 | paita
# Processing Record 34 of Set 6 | great yarmouth
# Processing Record 35 of Set 6 | caborca
# Processing Record 36 of Set 6 | doka
# Processing Record 37 of Set 6 | emilio carranza
# Processing Record 38 of Set 6 | inhambane
# Processing Record 39 of Set 6 | mhango
# Processing Record 40 of Set 6 | thoen
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 6 | yar-sale
# Processing Record 44 of Set 6 | pundaguitan
# Processing Record 45 of Set 6 | eureka
# Processing Record 46 of Set 6 | wamba
# Processing Record 47 of Set 6 | bam
# Processing Record 48 of Set 6 | cabo san lucas
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 50 of Set 6 | gaillac
# Processing Record 1 of Set 7 | monticello
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | klyuchi
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | kindu
# Processing Record 7 of Set 7 | tahoua
# Processing Record 8 of Set 7 | alofi
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | payson
# Processing Record 11 of Set 7 | staryy nadym
# Processing Record 12 of Set 7 | khandyga
# Processing Record 13 of Set 7 | mochishche
# Processing Record 14 of Set 7 | nagornskiy
# Processing Record 15 of Set 7 | vitim
# Processing Record 16 of Set 7 | palamos
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | bambanglipuro
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | beloha
# Processing Record 21 of Set 7 | iquique
# Processing Record 22 of Set 7 | oktyabrskoye
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | heinola
# Processing Record 25 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 7 | beipiao
# Processing Record 27 of Set 7 | gazli
# Processing Record 28 of Set 7 | kristianstad
# Processing Record 29 of Set 7 | juarez
# Processing Record 30 of Set 7 | chivilcoy
# Processing Record 31 of Set 7 | seddon
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | bambous virieux
# Processing Record 34 of Set 7 | letlhakeng
# Processing Record 35 of Set 7 | mahebourg
# Processing Record 36 of Set 7 | otukpo
# Processing Record 37 of Set 7 | hasaki
# Processing Record 38 of Set 7 | wenzhou
# Processing Record 39 of Set 7 | boden
# Processing Record 40 of Set 7 | aksu
# Processing Record 41 of Set 7 | yatou
# Processing Record 42 of Set 7 | matara
# Processing Record 43 of Set 7 | mountain home
# Processing Record 44 of Set 7 | freeport
# Processing Record 45 of Set 7 | barcelos
# Processing Record 46 of Set 7 | atbasar
# Processing Record 47 of Set 7 | sosnovo-ozerskoye
# Processing Record 48 of Set 7 | jalu
# Processing Record 49 of Set 7 | batticaloa
# Processing Record 50 of Set 7 | surt
# Processing Record 1 of Set 8 | changji
# Processing Record 2 of Set 8 | sainte-marie
# Processing Record 3 of Set 8 | magadan
# Processing Record 4 of Set 8 | norman wells
# Processing Record 5 of Set 8 | kalnciems
# Processing Record 6 of Set 8 | itoman
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | mezhdurechensk
# Processing Record 9 of Set 8 | ouadda
# Processing Record 10 of Set 8 | bad schwalbach
# Processing Record 11 of Set 8 | rundu
# Processing Record 12 of Set 8 | raha
# Processing Record 13 of Set 8 | uruzgan
# Processing Record 14 of Set 8 | thinadhoo
# Processing Record 15 of Set 8 | high level
# Processing Record 16 of Set 8 | conde
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | nador
# Processing Record 19 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 8 | bireun
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | lasa
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | hailar
# Processing Record 25 of Set 8 | dongsheng
# Processing Record 26 of Set 8 | terenos
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | humble
# Processing Record 29 of Set 8 | maceio
# Processing Record 30 of Set 8 | atasu
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 8 | juneau
# Processing Record 34 of Set 8 | asfi
# Processing Record 35 of Set 8 | lubango
# Processing Record 36 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 8 | valley city
# Processing Record 38 of Set 8 | muroto
# Processing Record 39 of Set 8 | takob
# City not found. Skipping...
# Processing Record 40 of Set 8 | casablanca
# Processing Record 41 of Set 8 | honningsvag
# Processing Record 42 of Set 8 | halifax
# Processing Record 43 of Set 8 | bacolod
# Processing Record 44 of Set 8 | auki
# Processing Record 45 of Set 8 | champerico
# Processing Record 46 of Set 8 | qasigiannguit
# Processing Record 47 of Set 8 | gemena
# Processing Record 48 of Set 8 | alexandria
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 9 | vila praia de ancora
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | gelemso
# Processing Record 4 of Set 9 | bol
# Processing Record 5 of Set 9 | shingu
# Processing Record 6 of Set 9 | hongjiang
# Processing Record 7 of Set 9 | sovetskiy
# Processing Record 8 of Set 9 | itaqui
# Processing Record 9 of Set 9 | ust-tsilma
# Processing Record 10 of Set 9 | half moon bay
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | kavaratti
# Processing Record 13 of Set 9 | dukhovnitskoye
# Processing Record 14 of Set 9 | hami
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | sitka
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 19 of Set 9 | tabou
# Processing Record 20 of Set 9 | windhoek
# Processing Record 21 of Set 9 | tecolutla
# Processing Record 22 of Set 9 | murgud
# Processing Record 23 of Set 9 | ilebo
# Processing Record 24 of Set 9 | guarapari
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 28 of Set 9 | galesong
# Processing Record 29 of Set 9 | moerai
# Processing Record 30 of Set 9 | miles city
# Processing Record 31 of Set 9 | singkang
# Processing Record 32 of Set 9 | samarai
# Processing Record 33 of Set 9 | necochea
# Processing Record 34 of Set 9 | ambilobe
# Processing Record 35 of Set 9 | elliot lake
# Processing Record 36 of Set 9 | kathu
# Processing Record 37 of Set 9 | bud
# Processing Record 38 of Set 9 | hualmay
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | salekhard
# Processing Record 41 of Set 9 | vangaindrano
# Processing Record 42 of Set 9 | henzada
# City not found. Skipping...
# Processing Record 43 of Set 9 | moctezuma
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | gigmoto
# Processing Record 46 of Set 9 | novobiryusinskiy
# Processing Record 47 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 9 | chiguiri arriba
# City not found. Skipping...
# Processing Record 49 of Set 9 | west fargo
# Processing Record 50 of Set 9 | worland
# Processing Record 1 of Set 10 | hibbing
# Processing Record 2 of Set 10 | saint-paul
# Processing Record 3 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 10 | brigantine
# Processing Record 5 of Set 10 | bandarbeyla
# Processing Record 6 of Set 10 | apatity
# Processing Record 7 of Set 10 | lyuban
# Processing Record 8 of Set 10 | murfreesboro
# Processing Record 9 of Set 10 | santa cruz de la palma
# Processing Record 10 of Set 10 | whitecourt
# Processing Record 11 of Set 10 | praia da vitoria
# Processing Record 12 of Set 10 | neuquen
# Processing Record 13 of Set 10 | krasnoselkup
# Processing Record 14 of Set 10 | sao joao da barra
# Processing Record 15 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 10 | loa janan
# Processing Record 17 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 10 | princeton
# Processing Record 19 of Set 10 | bendigo
# Processing Record 20 of Set 10 | colac
# Processing Record 21 of Set 10 | yulara
# Processing Record 22 of Set 10 | tamboril
# Processing Record 23 of Set 10 | tamandare
# Processing Record 24 of Set 10 | elizabeth city
# Processing Record 25 of Set 10 | zaoyang
# Processing Record 26 of Set 10 | alice springs
# Processing Record 27 of Set 10 | batalha
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | oranjemund
# Processing Record 30 of Set 10 | addis zemen
# City not found. Skipping...
# Processing Record 31 of Set 10 | talara
# Processing Record 32 of Set 10 | poum
# Processing Record 33 of Set 10 | longyearbyen
# Processing Record 34 of Set 10 | terney
# Processing Record 35 of Set 10 | hearst
# Processing Record 36 of Set 10 | vanimo
# Processing Record 37 of Set 10 | vershino-shakhtaminskiy
# Processing Record 38 of Set 10 | xuddur
# Processing Record 39 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 10 | pimentel
# Processing Record 41 of Set 10 | nalut
# Processing Record 42 of Set 10 | salalah
# Processing Record 43 of Set 10 | buchmany
# Processing Record 44 of Set 10 | mirina
# City not found. Skipping...
# Processing Record 45 of Set 10 | ntungamo
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | valparaiso
# Processing Record 48 of Set 10 | tarskoye
# Processing Record 49 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 50 of Set 10 | teahupoo
# Processing Record 1 of Set 11 | huancavelica
# Processing Record 2 of Set 11 | ndele
# Processing Record 3 of Set 11 | vryburg
# Processing Record 4 of Set 11 | businga
# Processing Record 5 of Set 11 | cairns
# Processing Record 6 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 11 | vaitape
# Processing Record 8 of Set 11 | kudahuvadhoo
# Processing Record 9 of Set 11 | shuangcheng
# Processing Record 10 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | birao
# Processing Record 12 of Set 11 | bucharest
# Processing Record 13 of Set 11 | hunfeld
# Processing Record 14 of Set 11 | beringovskiy
# Processing Record 15 of Set 11 | lumby
# Processing Record 16 of Set 11 | manado
# Processing Record 17 of Set 11 | veracruz
# Processing Record 18 of Set 11 | orange cove
# Processing Record 19 of Set 11 | ilhabela
# Processing Record 20 of Set 11 | horta
# Processing Record 21 of Set 11 | busayra
# Processing Record 22 of Set 11 | bontang
# Processing Record 23 of Set 11 | kachug
# Processing Record 24 of Set 11 | toora-khem
# Processing Record 25 of Set 11 | tual
# Processing Record 26 of Set 11 | pangody
# Processing Record 27 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 11 | baghdad
# Processing Record 29 of Set 11 | moindou
# Processing Record 30 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | outlook
# Processing Record 32 of Set 11 | colwyn bay
# Processing Record 33 of Set 11 | flinders
# Processing Record 34 of Set 11 | guantanamo
# Processing Record 35 of Set 11 | sept-iles
# Processing Record 36 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 11 | kangaatsiaq
# Processing Record 38 of Set 11 | ati
# Processing Record 39 of Set 11 | lata
# Processing Record 40 of Set 11 | avera
# Processing Record 41 of Set 11 | ostrovnoy
# Processing Record 42 of Set 11 | lahij
# Processing Record 43 of Set 11 | coihaique
# Processing Record 44 of Set 11 | redmond
# Processing Record 45 of Set 11 | hobyo
# Processing Record 46 of Set 11 | tessalit
# Processing Record 47 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 11 | mackay
# Processing Record 49 of Set 11 | quatre cocos
# Processing Record 50 of Set 11 | bo rai
# Processing Record 1 of Set 12 | buin
# Processing Record 2 of Set 12 | port maria
# Processing Record 3 of Set 12 | petersburg
# Processing Record 4 of Set 12 | ust-maya
# Processing Record 5 of Set 12 | isla vista
# Processing Record 6 of Set 12 | klyuchevskiy
# Processing Record 7 of Set 12 | dauphin
# Processing Record 8 of Set 12 | weihai
# Processing Record 9 of Set 12 | callaway
# Processing Record 10 of Set 12 | missao velha
# Processing Record 11 of Set 12 | shenjiamen
# Processing Record 12 of Set 12 | krasnyy luch
# Processing Record 13 of Set 12 | cap malheureux
# Processing Record 14 of Set 12 | manzhouli
# Processing Record 15 of Set 12 | llanes
# Processing Record 16 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 17 of Set 12 | mount isa
# Processing Record 18 of Set 12 | nueve de julio
# Processing Record 19 of Set 12 | denizli
# Processing Record 20 of Set 12 | naustdal
# Processing Record 21 of Set 12 | zhezkazgan
# Processing Record 22 of Set 12 | marshfield
# Processing Record 23 of Set 12 | klaksvik
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | murmashi
# Processing Record 26 of Set 12 | pandan
# Processing Record 27 of Set 12 | ponta delgada
# Processing Record 28 of Set 12 | jarocin
# Processing Record 29 of Set 12 | beian
# Processing Record 30 of Set 12 | tukrah
# Processing Record 31 of Set 12 | colares
# Processing Record 32 of Set 12 | williston
# Processing Record 33 of Set 12 | laguna
# Processing Record 34 of Set 12 | pineville
# Processing Record 35 of Set 12 | mogadishu
# Processing Record 36 of Set 12 | namatanai
# Processing Record 37 of Set 12 | manjakandriana
# Processing Record 38 of Set 12 | rorvik
# Processing Record 39 of Set 12 | san carlos de bariloche
# Processing Record 40 of Set 12 | quepos
# Processing Record 41 of Set 12 | sidi ali
# Processing Record 42 of Set 12 | iskateley
# Processing Record 43 of Set 12 | lebanon
# Processing Record 44 of Set 12 | abnub
# Processing Record 45 of Set 12 | saldanha
# Processing Record 46 of Set 12 | yueyang
# Processing Record 47 of Set 12 | diffa
# Processing Record 48 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 12 | laguna de perlas
# Processing Record 50 of Set 12 | nenjiang
# Processing Record 1 of Set 13 | huntsville
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | tonekabon
# Processing Record 4 of Set 13 | cachoeiras de macacu
# Processing Record 5 of Set 13 | trairi
# Processing Record 6 of Set 13 | lavumisa
# Processing Record 7 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 10 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 13 | kuito
# Processing Record 12 of Set 13 | ouallam
# Processing Record 13 of Set 13 | neryungri
# Processing Record 14 of Set 13 | sumbe
# Processing Record 15 of Set 13 | broken hill
# Processing Record 16 of Set 13 | moroto
# Processing Record 17 of Set 13 | siniscola
# Processing Record 18 of Set 13 | la orilla
# Processing Record 19 of Set 13 | paracelis
# Processing Record 20 of Set 13 | nagato
# Processing Record 21 of Set 13 | aswan
# Processing Record 22 of Set 13 | alihe
# Processing Record 23 of Set 13 | qui nhon
# Processing Record 24 of Set 13 | zolotukhino
# Processing Record 25 of Set 13 | taganak
# Processing Record 26 of Set 13 | alta floresta
# Processing Record 27 of Set 13 | sistranda
# Processing Record 28 of Set 13 | rethimnon
# Processing Record 29 of Set 13 | okakarara
# Processing Record 30 of Set 13 | sobolevo
# Processing Record 31 of Set 13 | wajir
# Processing Record 32 of Set 13 | gizo
# Processing Record 33 of Set 13 | boa vista
# Processing Record 34 of Set 13 | aksarka
# Processing Record 35 of Set 13 | leshukonskoye
# Processing Record 36 of Set 13 | conceicao do araguaia
# Processing Record 37 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 13 | kaposvar
# Processing Record 39 of Set 13 | alta
# Processing Record 40 of Set 13 | ibra
# Processing Record 41 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 13 | eregli
# Processing Record 43 of Set 13 | sidrolandia
# Processing Record 44 of Set 13 | kokoda
# Processing Record 45 of Set 13 | kalmunai
# Processing Record 46 of Set 13 | livingston
# Processing Record 47 of Set 13 | tocopilla
# Processing Record 48 of Set 13 | gouyave
# Processing Record 49 of Set 13 | moa
# Processing Record 50 of Set 13 | lakes entrance
# Processing Record 1 of Set 14 | kruisfontein
# Processing Record 2 of Set 14 | nishihara
# Processing Record 3 of Set 14 | puerto leguizamo
# Processing Record 4 of Set 14 | kutahya
# Processing Record 5 of Set 14 | alyangula
# Processing Record 6 of Set 14 | fukue
# Processing Record 7 of Set 14 | miri
# Processing Record 8 of Set 14 | nyurba
# Processing Record 9 of Set 14 | novoulyanovsk
# Processing Record 10 of Set 14 | ulagan
# Processing Record 11 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 12 of Set 14 | kysyl-syr
# Processing Record 13 of Set 14 | cabedelo
# Processing Record 14 of Set 14 | pasighat
# Processing Record 15 of Set 14 | tilichiki
# Processing Record 16 of Set 14 | emerald
# Processing Record 17 of Set 14 | maasbree
# Processing Record 18 of Set 14 | waingapu
# Processing Record 19 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 14 | matagami
# Processing Record 21 of Set 14 | grong
# Processing Record 22 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 23 of Set 14 | rocky mountain house
# Processing Record 24 of Set 14 | taoudenni
# Processing Record 25 of Set 14 | chicama
# Processing Record 26 of Set 14 | kendari
# Processing Record 27 of Set 14 | eyl
# Processing Record 28 of Set 14 | baringo
# Processing Record 29 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 30 of Set 14 | burica
# City not found. Skipping...
# Processing Record 31 of Set 14 | sur
# Processing Record 32 of Set 14 | kalabo
# Processing Record 33 of Set 14 | arrecife
# Processing Record 34 of Set 14 | batagay-alyta
# Processing Record 35 of Set 14 | san javier
# Processing Record 36 of Set 14 | prince albert
# Processing Record 37 of Set 14 | tikhvin
# Processing Record 38 of Set 14 | el paujil
# Processing Record 39 of Set 14 | puerto quijarro
# Processing Record 40 of Set 14 | cherkasskoye
# Processing Record 41 of Set 14 | katsuura
# Processing Record 42 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 43 of Set 14 | saint-joseph
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | severnoye
# Processing Record 46 of Set 14 | nawa
# Processing Record 47 of Set 14 | zilair
# Processing Record 48 of Set 14 | agadez
# Processing Record 49 of Set 14 | pullman
# Processing Record 50 of Set 14 | san lorenzo
# Processing Record 1 of Set 15 | okhotsk
# Processing Record 2 of Set 15 | belaya gora
# Processing Record 3 of Set 15 | belmonte
# Processing Record 4 of Set 15 | ostersund
# Processing Record 5 of Set 15 | koryazhma
# Processing Record 6 of Set 15 | gjusvik
# City not found. Skipping...
# Processing Record 7 of Set 15 | kununurra
# Processing Record 8 of Set 15 | nicolas bravo
# Processing Record 9 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 15 | den helder
# Processing Record 11 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 12 of Set 15 | sakakah
# Processing Record 13 of Set 15 | chancay
# Processing Record 14 of Set 15 | lindi
# Processing Record 15 of Set 15 | imeni babushkina
# Processing Record 16 of Set 15 | samarinda
# Processing Record 17 of Set 15 | jardim
# Processing Record 18 of Set 15 | beeville
# Processing Record 19 of Set 15 | north bend
# Processing Record 20 of Set 15 | doctor arroyo
# Processing Record 21 of Set 15 | smithers
# Processing Record 22 of Set 15 | bubaque
# Processing Record 23 of Set 15 | altos
# Processing Record 24 of Set 15 | buraydah
# Processing Record 25 of Set 15 | batemans bay
# Processing Record 26 of Set 15 | carepa
# Processing Record 27 of Set 15 | saint-fabien
# City not found. Skipping...
# Processing Record 28 of Set 15 | balykshi
# Processing Record 29 of Set 15 | korla
# Processing Record 30 of Set 15 | seguin
# Processing Record 31 of Set 15 | ballina
# Processing Record 32 of Set 15 | hay river
# Processing Record 33 of Set 15 | ussel
# Processing Record 34 of Set 15 | boyolangu
# Processing Record 35 of Set 15 | midland
# Processing Record 36 of Set 15 | portland
# Processing Record 37 of Set 15 | grenaa
# Processing Record 38 of Set 15 | nizhniy tsasuchey
# Processing Record 39 of Set 15 | izumo
# Processing Record 40 of Set 15 | bogorodskoye
# Processing Record 41 of Set 15 | baherden
# Processing Record 42 of Set 15 | beatrice
# Processing Record 43 of Set 15 | ouango
# Processing Record 44 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 15 | asau
# Processing Record 46 of Set 15 | stornoway
# Processing Record 47 of Set 15 | kloulklubed
# Processing Record 48 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 15 | outjo
# Processing Record 50 of Set 15 | nicoya
# Processing Record 1 of Set 16 | otorohanga
# Processing Record 2 of Set 16 | tuatapere
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         San Juan      AR -31.5375  -68.5364     77.13        28           1
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     75.16        69          75
# 2     Punta Arenas      CL -53.1500  -70.9167     48.31        66          40
# 3             Nuuk      GL  64.1835  -51.7216     27.21        63          20
# 4          Mataura      NZ -46.1927  168.8643     39.47        98          62
# 5          Chotila      IN  22.4167   71.1833     83.39        38           0
# 6            Vaini      TO -21.2000 -175.2000     77.16        88          75
# 7              Edd      ER  13.9297   41.6925     82.58        77          86
# 8          Ushuaia      AR -54.8000  -68.3000     44.26        61          40
# 9           Avarua      CK -21.2078 -159.7750     82.45        74          75
#
#    Wind Speed Current Description
# 0       12.48           clear sky
# 1       16.11       broken clouds
# 2        5.75    scattered clouds
# 3       10.36          few clouds
# 4        2.91       broken clouds
# 5       14.25           clear sky
# 6        4.61       broken clouds
# 7        4.63     overcast clouds
# 8       10.36    scattered clouds
# 9        2.30       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
